# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruv0050/Natural-Language-Processing---Concepts/blob/main/Tokenisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Tokenization in NLP is the process of breaking raw text into smaller units called tokens, which a computer can understand and process.**

# %% [markdown]
# **`Using NLTK library `**

# %%
# !pip install nltk

# %%
corpus = """
  Lorem ipsum dolor sit amet, consectetur adipiscing elit.
  Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
  Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.
 """

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.tokenize import wordpunct_tokenize
from nltk.tokenize import TreebankWordTokenizer

# %% [markdown]
# ***Paragraph to sentence tokenization***

# %%
sent_tokenize(corpus)
# Out:
# ['\n  Lorem ipsum dolor sit amet, consectetur adipiscing elit.',
#  'Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.',
#  'Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.']

# %% [markdown]
# ***Paragraph to words tokenization***

# %%
word_tokenize(corpus)
# Out:
# ['Lorem',
#  'ipsum',
#  'dolor',
#  'sit',
#  'amet',
#  ',',
#  'consectetur',
#  'adipiscing',
#  'elit',
#  '.',
#  'Sed',
#  'do',
#  'eiusmod',
#  'tempor',
#  'incididunt',
#  'ut',
#  'labore',
#  'et',
#  'dolore',
#  'magna',
#  'aliqua',
#  '.',
#  'Ut',
#  'enim',
#  'ad',
#  'minim',
#  'veniam',
#  ',',
#  'quis',
#  'nostrud',
#  'exercitation',
#  'ullamco',
#  'laboris',
#  'nisi',
#  'ut',
#  'aliquip',
#  'ex',
#  'ea',
#  'commodo',
#  'consequat',
#  '.']

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Lorem',
#  'ipsum',
#  'dolor',
#  'sit',
#  'amet',
#  ',',
#  'consectetur',
#  'adipiscing',
#  'elit',
#  '.',
#  'Sed',
#  'do',
#  'eiusmod',
#  'tempor',
#  'incididunt',
#  'ut',
#  'labore',
#  'et',
#  'dolore',
#  'magna',
#  'aliqua',
#  '.',
#  'Ut',
#  'enim',
#  'ad',
#  'minim',
#  'veniam',
#  ',',
#  'quis',
#  'nostrud',
#  'exercitation',
#  'ullamco',
#  'laboris',
#  'nisi',
#  'ut',
#  'aliquip',
#  'ex',
#  'ea',
#  'commodo',
#  'consequat',
#  '.']

# %%
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Lorem',
#  'ipsum',
#  'dolor',
#  'sit',
#  'amet',
#  ',',
#  'consectetur',
#  'adipiscing',
#  'elit.',
#  'Sed',
#  'do',
#  'eiusmod',
#  'tempor',
#  'incididunt',
#  'ut',
#  'labore',
#  'et',
#  'dolore',
#  'magna',
#  'aliqua.',
#  'Ut',
#  'enim',
#  'ad',
#  'minim',
#  'veniam',
#  ',',
#  'quis',
#  'nostrud',
#  'exercitation',
#  'ullamco',
#  'laboris',
#  'nisi',
#  'ut',
#  'aliquip',
#  'ex',
#  'ea',
#  'commodo',
#  'consequat',
#  '.']
